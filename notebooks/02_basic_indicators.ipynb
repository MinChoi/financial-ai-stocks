# %%
import yfinance as yf
import matplotlib.pyplot as plt

ticker = "AAPL"      # US
data = yf.download(ticker, period="1y", interval="1d")
data.head()

data["MA20"] = data["Close"].rolling(window=20).mean()
data["MA50"] = data["Close"].rolling(window=50).mean()
data["MA200"] = data["Close"].rolling(window=200).mean()


plt.figure(figsize=(10,5))
plt.plot(data["Close"], label="Close")
# MA20 in stock analysis means the 20-day Moving Average,
plt.plot(data["MA20"], label="MA20")
plt.plot(data["MA50"], label="MA50")
plt.legend()
plt.show()
# Out:
# Unable to revert mtime: /Library/Fonts
# Matplotlib is building the font cache; this may take a moment.
# /var/folders/44/dxr728kj4gz1490rmjpm6_6m0000gn/T/ipykernel_98314/3216982163.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="1y", interval="1d")
# [*********************100%***********************]  1 of 1 completed
